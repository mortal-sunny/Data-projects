# %% [markdown]
# # Sales Data Cleaning Project
# **Author:** Sunny
# **Dataset:** Superstore Sales — Kaggle (9,800 rows, 18 columns)
# **Tools:** Python, Pandas
# **Goal:** Load raw sales data, check and fix missing values, clean column names, export clean file to Excel for pivot analysis.
# **Finding:** Dataset had 11 missing Postal Code values — filled with 0. No duplicates found.

# %%
# !pip install kagglehub

# %%
import kagglehub

path = kagglehub.dataset_download("rohitsahoo/sales-forecasting")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Mahi\.cache\kagglehub\datasets\rohitsahoo\sales-forecasting\versions\2

# %%
import pandas as pd
import os

data_dir = r"C:\Users\Mahi\.cache\kagglehub\datasets\rohitsahoo\sales-forecasting\versions\2"

file_path = os.path.join(data_dir, "train.csv")

df = pd.read_csv(file_path)
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
print("Total rows and columns:",df.shape)
print("\nMissing values in each column:")
print(df.isnull().sum())
# Out:
# Total rows and columns: (9800, 18)
#
# Missing values in each column:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
print("Rows before cleaning:", len(df))

df = df.drop_duplicates()
df = df.fillna(0)
df.columns = df.columns.str.strip().str.lower().str.replace(' ','_')

print("rows after cleaning:", len(df))
print("\nColumn names now")
print(list(df.columns))
# Out:
# Rows before cleaning: 9800
# rows after cleaning: 9800
#
# Column names now
# ['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id', 'customer_name', 'segment', 'country', 'city', 'state', 'postal_code', 'region', 'product_id', 'category', 'sub-category', 'product_name', 'sales']

# %%
df.to_excel('Sunny_Cleaned_Sales.xlsx', index=False)
print("Cleaned data saved!")
# Out:
# Cleaned data saved!
